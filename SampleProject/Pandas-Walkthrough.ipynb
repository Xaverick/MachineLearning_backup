# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# ## Pandas Series

# %%
series = pd.Series(["Honda", "maruti","BMW"])
series
# Out:
# 0     Honda
# 1    maruti
# 2       BMW
# dtype: object

# %%
colors = pd.Series(["Blue", "Black", "White"])
colors
# Out:
# 0     Blue
# 1    Black
# 2    White
# dtype: object

# %% [markdown]
# ## DataFrames - 2 Dimensional

# %%
#DataFrame = 2-dimensional
car_data = pd.DataFrame({"Comapany": series,"colors":colors})
car_data
# Out:
#   Comapany colors
# 0    Honda   Blue
# 1   maruti  Black
# 2      BMW  White

# %% [markdown]
# ## Importing Downloaded Data

# %%
car_sales = pd.read_csv("./data/car-sales-extended.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %% [markdown]
#  ## Exporting Data
#
#  index=Flase removes the first column that shows the index

# %%
car_sales.to_csv("Exported_car_sales", index=False)
# car_sales.to_excel("Exported_car_sales")

# %%
exported_data = pd.read_csv("Exported_car_sales")
exported_data
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Describing The Data

# %%
#Attribute
car_sales.dtypes

#Function
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)        Doors         Price
# count    1000.000000  1000.000000   1000.000000
# mean   131073.708000     4.014000  16045.665000
# std     68859.723885     0.379405   8630.794219
# min     10148.000000     3.000000   2796.000000
# 25%     71238.000000     4.000000   9481.500000
# 50%    131202.000000     4.000000  14264.000000
# 75%    192372.750000     4.000000  20738.750000
# max    249860.000000     5.000000  52458.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           1000 non-null   object
#  1   Colour         1000 non-null   object
#  2   Odometer (KM)  1000 non-null   int64
#  3   Doors          1000 non-null   int64
#  4   Price          1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
car_sales.mean()
# Out:
# C:\Users\Karti\AppData\Local\Temp\ipykernel_1536\4073448239.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sales.mean()
# Odometer (KM)    131073.708
# Doors                 4.014
# Price             16045.665
# dtype: float64

# %%
car_sales["Doors"].sum()
# Out:
# 4014

# %%
car_sales.sum()
# Out:
# Make             HondaBMWHondaToyotaNissanHondaToyotaHondaNissa...
# Colour           WhiteBlueWhiteWhiteBlueRedBlueWhiteWhiteBlueWh...
# Odometer (KM)                                            131073708
# Doors                                                         4014
# Price                                                     16045665
# dtype: object

# %%
len(car_sales)
# Out:
# 1000

# %% [markdown]
# ## View And Selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043
# 5   Honda    Red          42652      4  23883
# 6  Toyota   Blue         163453      4   8473

# %%
car_sales.tail()
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732

# %%
car_sales.tail(3)
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732

# %%
#loc & .iloc

#providing custom index
animals = pd.Series(["cat","dog","lions","fish"],index=[3,3,9,6])

# %%
animals
# Out:
# 3      cat
# 3      dog
# 9    lions
# 6     fish
# dtype: object

# %%
animals.loc[3]
# Out:
# 3    cat
# 3    dog
# dtype: object

# %%
animals.loc[9]
# Out:
# 'lions'

# %%
car_sales.loc[3]
# Out:
# Make             Toyota
# Colour            White
# Odometer (KM)    154365
# Doors                 4
# Price             13434
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make             Toyota
# Colour            White
# Odometer (KM)    154365
# Doors                 4
# Price             13434
# Name: 3, dtype: object

# %%
#iloc - refers to position
#loc - refers to index
animals.iloc[3]
# Out:
# 'fish'

# %%
animals.loc[:3]
# Out:
# 3    cat
# 3    dog
# dtype: object

# %%
car_sales.loc[:3] #splicing the list python
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 3    Toyota  White         154365      4  13434
# 6    Toyota   Blue         163453      4   8473
# 15   Toyota   Blue         205592      4  16290
# 16   Toyota    Red          96742      4  34465
# 20   Toyota   Blue         124844      4  24130
# ..      ...    ...            ...    ...    ...
# 983  Toyota    Red         183330      4  14671
# 989  Toyota    Red          41735      4  13928
# 990  Toyota  White         173408      4   8082
# 995  Toyota  Black          35820      4  32042
# 999  Toyota   Blue         248360      4  12732
#
# [398 rows x 5 columns]

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 1       BMW   Blue         192714      5  19943
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# 6    Toyota   Blue         163453      4   8473
# 8    Nissan  White         130538      4   9374
# ..      ...    ...            ...    ...    ...
# 993  Nissan  Black         162523      4   4696
# 994     BMW   Blue         163322      3  31666
# 996  Nissan  White         155144      3   5716
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [627 rows x 5 columns]

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors    3    4   5
# Make
# BMW     21    0  79
# Honda    0  304   0
# Nissan  44  154   0
# Toyota   0  398   0

# %%
#Groupby - Same As My Sql
car_sales.groupby(["Make"]).mean()
# Out:
# C:\Users\Karti\AppData\Local\Temp\ipykernel_1536\1820046094.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby(["Make"]).mean()
#         Odometer (KM)     Doors         Price
# Make
# BMW     123540.800000  4.580000  27089.830000
# Honda   124667.671053  4.000000  14514.200658
# Nissan  135480.308081  3.777778  13658.368687
# Toyota  135667.223618  4.000000  15628.160804

# %%
car_sales.groupby(["Make"]).max()
# Out:
#        Colour  Odometer (KM)  Doors  Price
# Make
# BMW     White         245427      5  52458
# Honda   White         248899      4  30854
# Nissan  White         249860      4  31633
# Toyota  White         248815      4  35988

# %%
car_sales.groupby(["Make"]).max()
# Out:
#        Colour  Odometer (KM)  Doors  Price
# Make
# BMW     White         245427      5  52458
# Honda   White         248899      4  30854
# Nissan  White         249860      4  31633
# Toyota  White         248815      4  35988

# %%
# %matplotlib inline
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Converting the data type of a column

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)  
#converting strings to integer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
#       2 #converting strings to integer
#
# File c:\Users\Karti\Coding\MachineLearning\SampleProject\env\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File c:\Users\Karti\Coding\MachineLearning\SampleProject\env\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
# ...

# %%
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Data Manipulation

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     honda  White          35431      4  15323
# 1       bmw   Blue         192714      5  19943
# 2     honda  White          84714      4  28343
# 3    toyota  White         154365      4  13434
# 4    nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  toyota  Black          35820      4  32042
# 996  nissan  White         155144      3   5716
# 997  nissan   Blue          66604      4  31570
# 998   honda  White         215883      4   4001
# 999  toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales_missing = pd.read_csv("./data/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# # fillna feature

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped")

# %%
#Column from series
seats_column = pd.Series([5,5,5,5,5])

#Adding the column to database
car_sales["seats"] = seats_column

# %%
car_sales["seats"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  seats
# 0     honda  White          35431      4  15323    5.0
# 1       bmw   Blue         192714      5  19943    5.0
# 2     honda  White          84714      4  28343    5.0
# 3    toyota  White         154365      4  13434    5.0
# 4    nissan   Blue         181577      3  14043    5.0
# ..      ...    ...            ...    ...    ...    ...
# 995  toyota  Black          35820      4  32042    5.0
# 996  nissan  White         155144      3   5716    5.0
# 997  nissan   Blue          66604      4  31570    5.0
# 998   honda  White         215883      4   4001    5.0
# 999  toyota   Blue         248360      4  12732    5.0
#
# [1000 rows x 6 columns]

# %%
#2nd method to add column
# Python list
fuel_ecomomy = [2,5,6.5,3,7,10,3.5,7.5,4,8]
car_sales["Fuel Per 100KM"] = fuel_ecomomy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 4
#       1 #2nd method to add column
#       2 # Python list
#       3 fuel_ecomomy = [2,5,6.5,3,7,10,3.5,7.5,4,8]
# ----> 4 car_sales["Fuel Per 100KM"] = fuel_ecomomy
#
# File c:\Users\Karti\Coding\MachineLearning\SampleProject\env\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File c:\Users\Karti\Coding\MachineLearning\SampleProject\env\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# ...

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  seats
# 0     honda  White          35431      4  15323    5.0
# 1       bmw   Blue         192714      5  19943    5.0
# 2     honda  White          84714      4  28343    5.0
# 3    toyota  White         154365      4  13434    5.0
# 4    nissan   Blue         181577      3  14043    5.0
# ..      ...    ...            ...    ...    ...    ...
# 995  toyota  Black          35820      4  32042    5.0
# 996  nissan  White         155144      3   5716    5.0
# 997  nissan   Blue          66604      4  31570    5.0
# 998   honda  White         215883      4   4001    5.0
# 999  toyota   Blue         248360      4  12732    5.0
#
# [1000 rows x 6 columns]

# %%
car_sales["Total Fuel Used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel Per 100KM"]
car_sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Karti\Coding\MachineLearning\SampleProject\env\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Karti\Coding\MachineLearning\SampleProject\env\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Karti\Coding\MachineLearning\SampleProject\env\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fuel Per 100KM'
#
# ...

# %%
car_sales["Number Of Wheels"] = 4

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  seats  Number Of Wheels
# 0     honda  White          35431      4  15323    5.0                 4
# 1       bmw   Blue         192714      5  19943    5.0                 4
# 2     honda  White          84714      4  28343    5.0                 4
# 3    toyota  White         154365      4  13434    5.0                 4
# 4    nissan   Blue         181577      3  14043    5.0                 4
# ..      ...    ...            ...    ...    ...    ...               ...
# 995  toyota  Black          35820      4  32042    5.0                 4
# 996  nissan  White         155144      3   5716    5.0                 4
# 997  nissan   Blue          66604      4  31570    5.0                 4
# 998   honda  White         215883      4   4001    5.0                 4
# 999  toyota   Blue         248360      4  12732    5.0                 4
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Shuffling Data

# %%
car_sales_shuffled =car_sales.sample(frac=1) # 1 for 100% of data
car_sales_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  seats  Number Of Wheels
# 340   honda  White          80664      4  20981    5.0                 4
# 650  toyota   Blue          23637      4  35281    5.0                 4
# 447  toyota   Blue          98619      4  33324    5.0                 4
# 129  toyota  White          94818      4  35358    5.0                 4
# 89   toyota   Blue          90249      4  35988    5.0                 4
# ..      ...    ...            ...    ...    ...    ...               ...
# 50   toyota    Red         184878      4   7445    5.0                 4
# 130  nissan   Blue          18994      4   7813    5.0                 4
# 322  toyota   Blue         165301      4  10429    5.0                 4
# 25    honda   Blue         125819      4  15686    5.0                 4
# 217  toyota  White         183368      4  18198    5.0                 4
#
# [1000 rows x 7 columns]

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  seats  Number Of Wheels
# 0     honda  White          80664      4  20981    5.0                 4
# 1    toyota   Blue          23637      4  35281    5.0                 4
# 2    toyota   Blue          98619      4  33324    5.0                 4
# 3    toyota  White          94818      4  35358    5.0                 4
# 4    toyota   Blue          90249      4  35988    5.0                 4
# ..      ...    ...            ...    ...    ...    ...               ...
# 995  toyota    Red         184878      4   7445    5.0                 4
# 996  nissan   Blue          18994      4   7813    5.0                 4
# 997  toyota   Blue         165301      4  10429    5.0                 4
# 998   honda   Blue         125819      4  15686    5.0                 4
# 999  toyota  White         183368      4  18198    5.0                 4
#
# [1000 rows x 7 columns]
